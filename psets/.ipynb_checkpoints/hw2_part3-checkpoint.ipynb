# %%
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.metrics import accuracy_score, classification_report,confusion_matrix, f1_score, precision_score, recall_score
from catboost import CatBoostClassifier
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder
from sklearn.tree import DecisionTreeClassifier, DecisionTreeRegressor
from sklearn import tree

import time
from sklearn.ensemble import RandomForestClassifier, RandomForestRegressor
from sklearn.linear_model import LogisticRegression



import shap

# %%
# !pip install bertopic
from bertopic.representation import ZeroShotClassification
from bertopic import BERTopic
from transformers import pipeline
## This takes about one minute
# Out:
# Requirement already satisfied: bertopic in /opt/anaconda3/lib/python3.11/site-packages (0.16.4)
# Requirement already satisfied: hdbscan>=0.8.29 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (0.8.39)
# Requirement already satisfied: numpy>=1.20.0 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (1.26.4)
# Requirement already satisfied: pandas>=1.1.5 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (2.1.4)
# Requirement already satisfied: plotly>=4.7.0 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (5.9.0)
# Requirement already satisfied: scikit-learn>=0.22.2.post1 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (1.2.2)
# Requirement already satisfied: sentence-transformers>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (3.2.1)
# Requirement already satisfied: tqdm>=4.41.1 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (4.66.5)
# Requirement already satisfied: umap-learn>=0.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from bertopic) (0.5.6)
# Requirement already satisfied: scipy>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from hdbscan>=0.8.29->bertopic) (1.11.4)
# Requirement already satisfied: joblib>=1.0 in /opt/anaconda3/lib/python3.11/site-packages (from hdbscan>=0.8.29->bertopic) (1.2.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.5->bertopic) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.5->bertopic) (2023.3.post1)
# Requirement already satisfied: tzdata>=2022.1 in /opt/anaconda3/lib/python3.11/site-packages (from pandas>=1.1.5->bertopic) (2023.3)
# Requirement already satisfied: tenacity>=6.2.0 in /opt/anaconda3/lib/python3.11/site-packages (from plotly>=4.7.0->bertopic) (8.2.2)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.11/site-packages (from scikit-learn>=0.22.2.post1->bertopic) (2.2.0)
# Requirement already satisfied: transformers<5.0.0,>=4.41.0 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (4.45.2)
# Requirement already satisfied: torch>=1.11.0 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (2.4.1)
# Requirement already satisfied: huggingface-hub>=0.20.0 in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (0.26.1)
# Requirement already satisfied: Pillow in /opt/anaconda3/lib/python3.11/site-packages (from sentence-transformers>=0.4.1->bertopic) (10.2.0)
# Requirement already satisfied: numba>=0.51.2 in /opt/anaconda3/lib/python3.11/site-packages (from umap-learn>=0.5.0->bertopic) (0.59.0)
# Requirement already satisfied: pynndescent>=0.5 in /opt/anaconda3/lib/python3.11/site-packages (from umap-learn>=0.5.0->bertopic) (0.5.13)
# Requirement already satisfied: filelock in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.13.1)
# Requirement already satisfied: fsspec>=2023.5.0 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2023.10.0)
# Requirement already satisfied: packaging>=20.9 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (23.1)
# Requirement already satisfied: pyyaml>=5.1 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (6.0.1)
# Requirement already satisfied: requests in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.32.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/anaconda3/lib/python3.11/site-packages (from huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (4.9.0)
# Requirement already satisfied: llvmlite<0.43,>=0.42.0dev0 in /opt/anaconda3/lib/python3.11/site-packages (from numba>=0.51.2->umap-learn>=0.5.0->bertopic) (0.42.0)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.11/site-packages (from python-dateutil>=2.8.2->pandas>=1.1.5->bertopic) (1.16.0)
# Requirement already satisfied: sympy in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.12)
# Requirement already satisfied: networkx in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1)
# Requirement already satisfied: jinja2 in /opt/anaconda3/lib/python3.11/site-packages (from torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (3.1.3)
# Requirement already satisfied: regex!=2019.12.17 in /opt/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (2023.10.3)
# Requirement already satisfied: safetensors>=0.4.1 in /opt/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.4.5)
# Requirement already satisfied: tokenizers<0.21,>=0.20 in /opt/anaconda3/lib/python3.11/site-packages (from transformers<5.0.0,>=4.41.0->sentence-transformers>=0.4.1->bertopic) (0.20.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/anaconda3/lib/python3.11/site-packages (from jinja2->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.0.4)
# Requirement already satisfied: idna<4,>=2.5 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2.0.7)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/anaconda3/lib/python3.11/site-packages (from requests->huggingface-hub>=0.20.0->sentence-transformers>=0.4.1->bertopic) (2024.2.2)
# Requirement already satisfied: mpmath>=0.19 in /opt/anaconda3/lib/python3.11/site-packages (from sympy->torch>=1.11.0->sentence-transformers>=0.4.1->bertopic) (1.3.0)

# %%
df1 = pd.read_csv('qss45_data/shohei.csv')

# %%
df1['statistics.views_date_last_refreshed'].value_counts()
# Out:
# statistics.views_date_last_refreshed
# 2024-10-21    25649
# 2024-10-24     1350
# 2024-10-23      891
# 2024-10-22      494
# 2024-10-05      229
# 2024-10-14      214
# 2024-10-19      203
# 2024-10-20      201
# 2024-10-13      160
# 2024-10-15      157
# 2024-10-12      152
# 2024-10-17      145
# 2024-10-16      127
# 2024-10-18      120
# 2024-10-03      113
# 2024-10-02      113
# 2024-10-10      109
# 2024-10-11      106
# 2024-10-08       89
# 2024-10-04       87
# 2024-10-06       75
# 2024-10-09        1
# Name: count, dtype: int64

# %%
selected_cols = ['content_type', 'creation_time', 'hashtags', 'is_branded_content',
                 'lang', 'match_type', 'post_owner.type', 'post_owner.username',
                 'statistics.comment_count', 'statistics.like_count', 'statistics.views', 'text']

df_2 = df1[selected_cols].copy()

# %%
df_2
# Out:
#       content_type              creation_time  \
# 0           photos  2024-10-24T13:12:33-07:00
# 1           photos  2024-10-24T13:03:01-07:00
# 2           videos  2024-10-24T12:51:00-07:00
# 3           photos  2024-10-24T12:43:14-07:00
# 4           albums  2024-10-24T12:41:20-07:00
# ...            ...                        ...
# 30971       photos  2023-10-23T23:38:17-07:00
# 30972       videos  2023-10-23T21:03:15-07:00
# 30973       albums  2023-10-23T20:37:28-07:00
# 30974       albums  2023-10-23T20:30:19-07:00
# 30975       albums  2023-10-23T20:25:51-07:00
#
#                                                 hashtags  is_branded_content  \
# 0      ["shoheiohtani","lawsuit","ohtani","recordbrea...               False
# 1      ["emisi\u00f3nestelarnt5","ntelemicro5","shohe...               False
# 2      ["misiondeportiva","beisbol","shoheiohtani","d...               False
# 3                                                    NaN               False
# 4            ["shoheiohtani","dodgers","mlb","baseball"]               False
# ...                                                  ...                 ...
# 30971  ["shoheiohtani","baseballcards","rookiecard","...               False
# 30972           ["sasqatchfabrix","needles","nepenthes"]               False
# 30973  ["shoheiohtani","japan","17","baseball","custo...               False
# 30974        ["shoheiohtani","\u5927\u8c37\u7fd4\u5e73"]               False
# 30975  ["\u4e2d\u76ee\u9ed2sml","\u5927\u8c37\u54f2\u...               False
#
#       lang     match_type post_owner.type  post_owner.username  \
# 0       en  ["post_text"]        business                  NaN
# 1       es  ["post_text"]        business                  NaN
# 2       es  ["post_text"]         creator                  NaN
# 3       es  ["post_text"]        business                  NaN
# 4       en  ["post_text"]        business                  NaN
# ...    ...            ...             ...                  ...
# 30971   en  ["post_text"]        business                  NaN
# 30972   en  ["post_text"]        business                  NaN
# 30973   en  ["post_text"]        business                  NaN
# 30974   ja  ["post_text"]        personal                  NaN
# 30975   ja  ["post_text"]        business                  NaN
#
#        statistics.comment_count  statistics.like_count  statistics.views  \
# 0                           0.0                    4.0               NaN
# 1                           1.0                   11.0               NaN
# 2                           0.0                    2.0               NaN
# 3                           0.0                    8.0               NaN
# 4                           7.0                  426.0               NaN
# ...                         ...                    ...               ...
# 30971                       0.0                   45.0            3896.0
# 30972                      11.0                    NaN          221327.0
# 30973                       0.0                    3.0             372.0
# 30974                      51.0                 8835.0          351426.0
# 30975                       4.0                  425.0           44612.0
#
#                                                     text
# 0      Shohei Ohtani’s historic 50-50 baseball sold f...
# 1      Con grandes nombres como Aaron Judge, Juan Sot...
# 2      "OHTANI ES EL MEJOR JUGADOR DEL JUEGO" \n\n- A...
# 3      Con el japonés Shohei Ohtani y con Aaron Judge...
# 4      Tyler Glasnow’s thoughts on if there’s any cha...
# ...                                                  ...
# 30971  Shohei Ohtani 2017 Bowman Chrome Mega Box Refr...
# 30972  〈NEEDLES〉x〈Sasquatchfabrix.〉COLLABORATION PROD...
# 30973  Los Angeles Angels, Shohei Ohtani 17\n\n#17 #j...
# 30974  🩵‎🤍爽やかー♡\n(📸2021©AQUARIUS)髪の毛長めな感じ💙\nPSの盛り上がりの...
# 30975  【常設】\n⁡\n本日から始まる常設では新入荷の商品を中心にご案内します。\n⁡\n小代焼ふ...
#
# [30976 rows x 12 columns]

# %%
labels = [ "negative restaurant", "positive restaurant",]

def review_pipe(text):
    output = pipe(text,
                  candidate_labels = labels,
                 )
    labs = output["labels"]
    return labs[0]

# %%
# %%time
df_s = df.sample(n=100)
df_s["y_pred"] = df_s.raw_text.apply(review_pipe)

# %%
lab2binary = dict(zip(labels,range(2)))
df_s["y_pred_binary"] = df_s.y_pred.apply(lambda x: lab2binary[x])

# %%
print("F1 Score is: ",  f1_score(df_s.y_pred_binary, df_s.metadata_label) )
print("Precision is: ", precision_score(df_s.y_pred_binary, df_s.metadata_label) )
print("Recall is: ",    recall_score(df_s.y_pred_binary, df_s.metadata_label)  )
